# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import *
# %matplotlib inline
sns.set(style="ticks")
def make_dataframe(ds_function):
    ds = ds_function()
    df = pd.DataFrame(data= np.c_[ds['data'], ds['target']],
                     columns= list(ds['feature_names']) + ['target'])
    return df
data = make_dataframe(load_diabetes)
data.head()
data.shape
data.columns
data.dtypes
for col in data.columns:
    temp_null_count = data[data[col].isnull()].shape[0]
    print('{} - {}'.format(col, temp_null_count))
data.describe()
data['target'].unique()
fig, ax = plt.subplots(figsize=(10,10))
sns.distplot(data['bmi'])
fig, ax = plt.subplots(figsize=(10,10))
sns.distplot(data['bp'])
fig, ax = plt.subplots(figsize=(10,10))
sns.scatterplot(ax=ax, x='age', y='bp', data=data)
fig, ax = plt.subplots(figsize=(10,10))
sns.scatterplot(ax=ax, x='bmi', y='s1', data=data)
fig, ax = plt.subplots(figsize=(10,10))
sns.boxplot(x='sex', y='bmi', data=data)
fig, ax = plt.subplots(1, 3, sharex='col', sharey='row', figsize=(15,5))
sns.heatmap(data.corr(method='pearson'), ax=ax[0], annot=True, fmt='.2f')
sns.heatmap(data.corr(method='kendall'), ax=ax[1], annot=True, fmt='.2f')
sns.heatmap(data.corr(method='spearman'), ax=ax[2], annot=True, fmt='.2f')
fig.suptitle('Корреляционные матрицы, построенные различными методами')
ax[0].title.set_text('Pearson')
ax[1].title.set_text('Kendall')
ax[2].title.set_text('Spearman')
# Out:
# age - 0
# sex - 0
# bmi - 0
# bp - 0
# s1 - 0
# s2 - 0
# s3 - 0
# s4 - 0
# s5 - 0
# s6 - 0
# target - 0
# /tmp/ipykernel_3345/3853699927.py:24: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['bmi'])
# /tmp/ipykernel_3345/3853699927.py:26: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['bp'])
